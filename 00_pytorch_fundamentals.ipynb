# %% [markdown]
# <a href="https://colab.research.google.com/github/SARTHxJAIN/pytorch/blob/main/00_pytorch_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib as plt
